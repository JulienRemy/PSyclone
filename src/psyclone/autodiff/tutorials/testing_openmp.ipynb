# %% [markdown]
# # PSyclone reverse mode automatic differentiation
# ## `psyclone.autodiff`
#
# ### 1. Differentiating some outputs of a subroutine with respect to some input variables
#
# Let us first define two trivial Fortran subroutines.

# %%
source = """
subroutine qux(a, b, w)
    implicit none
    real, intent(inout) :: a(10, 10)
    real, intent(out) :: b(10, 10, 10, 10)
    real, intent(in) :: w

    integer :: i, j, k

    do i = 1, 10
        do j = 1, 9
            k = 3
            b(i,j,k,4) = a(i,j-1)*a(i,j+1)
        end do
    end do

end subroutine qux
"""

from psyclone.autodiff.transformations import ADReverseContainerTrans
from psyclone.psyir.frontend.fortran import FortranReader
from psyclone.psyir.backend.fortran import FortranWriter
from psyclone.psyir.nodes import Container, Routine, Reference, Call, OMPParallelDoDirective, Schedule
from psyclone.autodiff import ADJointReversalSchedule, ADSplitReversalSchedule, ADLinkReversalSchedule

# Front- and backend
freader = FortranReader()
fwriter = FortranWriter()

# PSyIR
psy = freader.psyir_from_source(source)

# Get the container
container = psy.walk(Container)[0]
routine = container.children[0]
children = routine.pop_all_children()
routine.addchild(OMPParallelDoDirective(children=children))

# Initialize the container transformation
container_trans = ADReverseContainerTrans()

# What to differentiate and wrt to what
# d{dependent}/d{independent}
# routine_name = 'foo'
# dependent_vars = ['f','g']
# independent_vars = ['x','w']
routine_name = 'qux'
dependent_vars = ['b']
independent_vars = ['a','w']

# Reversal schedules that are available at this date
split_schedule = ADSplitReversalSchedule()
joint_schedule = ADJointReversalSchedule()
link_schedule = ADLinkReversalSchedule( strong_links=[['foo', 'bar']],
                                        #weak_links=[['foo', 'bar']],
                                        default_link='weak')
reversal_schedule = joint_schedule

# Available options, for now
options = {'verbose': False,                     # default is False
           'jacobian': False,                    # default is False
           'simplify': True,                    # default is True
           'simplify_times': 5,                 # default is 5
           'inline_operation_adjoints': True}   # default is True

# Apply the transformation
result = container_trans.apply(container, 
                               routine_name, 
                               dependent_vars, 
                               independent_vars, 
                               reversal_schedule, 
                               options=options)



# print(result.view())

from psyclone.line_length import FortLineLength

# Transformed source
print(FortLineLength().process(fwriter(result)))
# Out:
# a_adj: DataSymbol<Array<Scalar<REAL, UNDEFINED>, shape=[10, 10]>, Automatic>
# Original assignment:  a_adj(i,j - 1) = a_adj(i,j - 1) + b_adj(i,j,k,4) * a(i,j + 1)
#
# Original loop bounds:  ['1', '9']
# Transformed assignment:  a_adj(i,j) = a_adj(i,j + 1 - 1) + b_adj(i,j + 1,k,4) * a(i,j + 1 + 1)
#
# Transformed bounds:  [['1', '10'], ['1 - 1', '9 - 1']]
# Transformed interval:  ProductSet(Interval(1, 10), Interval(0, 8))
# a_adj: DataSymbol<Array<Scalar<REAL, UNDEFINED>, shape=[10, 10]>, Automatic>
# Original assignment:  a_adj(i,j + 1) = a_adj(i,j + 1) + b_adj(i,j,k,4) * a(i,j - 1)
#
# Original loop bounds:  ['1', '9']
# Transformed assignment:  a_adj(i,j) = a_adj(i,j - 1 + 1) + b_adj(i,j - 1,k,4) * a(i,j - 1 - 1)
#
# Transformed bounds:  [['1', '10'], ['1 + 1', '9 + 1']]
# Transformed interval:  ProductSet(Interval(1, 10), Interval(2, 10))
# Intersection: ProductSet(Interval(1, 10), Interval(2, 8))
# Union: ProductSet(Interval(1, 10), Interval(0, 10))
# Intersection to bounds: [[[10, 1], [8, 2]]]
# loop was  do i = 10, 1, -1
#   do j = 9, 1, -1
#     b(i,j,k,4) = value_tape_real_qux(value_tape_real_qux_do_offset + 1)
#     !$omp atomic
#     a_adj(i,j - 1) = a_adj(i,j - 1) + b_adj(i,j,k,4) * a(i,j + 1)
#     !$omp end atomic
#     !$omp atomic
#     a_adj(i,j + 1) = a_adj(i,j + 1) + b_adj(i,j,k,4) * a(i,j - 1)
#     !$omp end atomic
#     b_adj(i,j,k,4) = 0.0
#     k = value_tape_integer_qux(value_tape_integer_qux_do_offset + 1)
#     k_adj = 0.0
#   enddo
# enddo
#
# now is  do i = 10, 1, -1
#   do j = 8, 2, -1
#     b(i,j,k,4) = value_tape_real_qux(value_tape_real_qux_do_offset + 1)
#     !$omp atomic
#     a_adj(i,j - 1) = a_adj(i,j - 1) + b_adj(i,j,k,4) * a(i,j + 1)
#     !$omp end atomic
#     !$omp atomic
#     a_adj(i,j + 1) = a_adj(i,j + 1) + b_adj(i,j,k,4) * a(i,j - 1)
#     !$omp end atomic
#     b_adj(i,j,k,4) = 0.0
#     k = value_tape_integer_qux(value_tape_integer_qux_do_offset + 1)
#     k_adj = 0.0
#   enddo
# enddo
# ---------------------------------------------------------------------------
# GenerationError                           Traceback (most recent call last)
# /tmp/ipykernel_272363/4240330420.py in <module>
#      65
#      66 # Apply the transformation
# ---> 67 result = container_trans.apply(container,
#      68                                routine_name,
#      69                                dependent_vars,
#
# ~/.local/lib/python3.10/site-packages/psyclone/autodiff/transformations/reverse_mode/ad_reverse_container_trans.py in apply(self, container, routine_name, dependent_vars, independent_vars, reversal_schedule, options)
#     281
#     282         # Transform the Routine
# --> 283         routine_trans.apply(
#     284             routine,
#     285             dependent_vars,
#
# ~/.local/lib/python3.10/site-packages/psyclone/autodiff/transformations/reverse_mode/ad_reverse_routine_trans.py in apply(self, routine, dependent_vars, independent_vars, value_tapes, control_tape, options)
#     685
#     686         # Transform the statements found in the Routine
# --> 687         self.transform_children(options)
#     688
#     689         # Add the transformed routines symbols to the container_trans map
#
# ~/.local/lib/python3.10/site-packages/psyclone/autodiff/transformations/reverse_mode/ad_reverse_routine_trans.py in transform_children(self, options)
#    1151                 (recording, returning) = self.transform_loop(child, options)
#    1152             elif isinstance(child, OMPRegionDirective):
# -> 1153                 (recording, returning) = self.omp_region_trans.apply(
#    1154                     child, options
#    1155                 )
#
# ~/.local/lib/python3.10/site-packages/psyclone/autodiff/transformations/reverse_mode/ad_reverse_omp_region_directive_trans.py in apply(self, omp_region, options)
#      93         body = omp_region.dir_body
#      94         # Transform the if body to get both motions
# ---> 95         (recording_body, returning_body) = self.transform_body(body, options)
#      96         returning_body.reverse()
#      97
#
# ~/.local/lib/python3.10/site-packages/psyclone/autodiff/transformations/reverse_mode/ad_reverse_omp_region_directive_trans.py in transform_body(self, body, options)
#     299                 recording.extend(rec)
#     300             elif isinstance(child, Loop):
# --> 301                 (recording, returning) = self.routine_trans.transform_loop(
#     302                     child, options
#     303                 )
#
# ~/.local/lib/python3.10/site-packages/psyclone/autodiff/transformations/reverse_mode/ad_reverse_routine_trans.py in transform_loop(self, loop, options)
#    1122
#    1123         # Apply the transformation
# -> 1124         recording, returning = self.loop_trans.apply(loop, options)
#    1125
#    1126         return recording, returning
#
# ~/.local/lib/python3.10/site-packages/psyclone/autodiff/transformations/reverse_mode/ad_reverse_loop_trans.py in apply(self, loop, options)
#     193                     self.routine_trans
#     194                 )
# --> 195                 return parallel_loop_trans.apply(loop, options)
#     196
#     197         recording = []
#
# ~/.local/lib/python3.10/site-packages/psyclone/autodiff/transformations/reverse_mode/ad_reverse_loop_trans.py in apply(self, loop, options)
#     345
#     346         if isinstance(self, ADReverseParallelLoopTrans):
# --> 347             self.transform_scatter_adjoints_to_gather_adjoints(returning_loop, loop.ancestor(Routine).symbol_table)
#     348
#     349         # verbose option adds comments to the returning do loop
#
# ~/.local/lib/python3.10/site-packages/psyclone/autodiff/transformations/reverse_mode/ad_reverse_parallel_loop_trans.py in transform_scatter_adjoints_to_gather_adjoints(self, returning_outer_loop, symbol_table, options)
#     619                                 # TODO: no loop for single value
#     620                                 new_start, new_stop = single_loop_bounds
# --> 621                                 new_loop = Loop.create(loop_var, new_start, new_stop, step, [])
#     622                                 if i == 0:
#     623                                     nested_loop = new_loop
#
# ~/.local/lib/python3.10/site-packages/psyclone/psyir/nodes/loop.py in create(cls, variable, start, stop, step, children)
#     202         loop = cls(variable=variable)
#     203         schedule = Schedule(parent=loop, children=children)
# --> 204         loop.children = [start, stop, step, schedule]
#     205         return loop
#     206
#
# ~/.local/lib/python3.10/site-packages/psyclone/psyir/nodes/node.py in children(self, my_children)
#     945             self._children = ChildrenList(self, self._validate_child,
#     946                                           self._children_valid_format)
# --> 947             self._children.extend(my_children)
#     948         else:
#     949             raise TypeError("The 'my_children' parameter of the node.children"
#
# ~/.local/lib/python3.10/site-packages/psyclone/psyir/nodes/node.py in extend(self, items)
#     255         '''
#     256         for index, item in enumerate(items):
# --> 257             self._validate_item(len(self) + index, item)
#     258             self._check_is_orphan(item)
#     259         super().extend(items)
#
# ~/.local/lib/python3.10/site-packages/psyclone/psyir/nodes/node.py in _validate_item(self, index, item)
#     142                           f"'{self._validation_text}'.")
#     143
# --> 144             raise GenerationError(errmsg)
#     145
#     146     def _check_is_orphan(self, item):
#
# GenerationError: Generation Error: Item 'Integer' can't be child 0 of 'Loop'. The valid format is: 'DataNode, DataNode, DataNode, Schedule'.
